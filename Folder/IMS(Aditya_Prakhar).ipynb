# %%
record = { 101 : {"product name" : "Dairy milk" , "product category" : "chocolate" , "MFG Date" : "22-06-2021" , "Price" : 10 , "Expiry Date" : "22-12-2021" ,"Weight" : "10gm","Quantity" : 800},
           102 : {"product name" : "5-star" , "product category" : "chocolate" , "MFG Date" : "22-06-2021" , "Price" : 10 , "Expiry Date" : "22-12-2021" ,"Weight" : "10gm","Quantity" : 400},
           103 : {"product name" : "kitkat" , "product category" : "chocolate" , "MFG Date" : "22-06-2021" , "Price" : 10 , "Expiry Date" : "22-12-2021" ,"Weight" : "10gm","Quantity" : 400},
           104 : {"product name" : "Dairy Milk silk" , "product category" : "chocolate" , "MFG Date" : "22-06-2021" , "Price" : 80 , "Expiry Date" : "22-12-2021" ,"Weight" : "100gm","Quantity" : 800},
           105 : {"product name" : "5-star" , "product category" : "chocolate" , "MFG Date" : "22-06-2021" , "Price" : 60 , "Expiry Date" : "22-12-2021" ,"Weight" : "70gm","Quantity" : 600},
           106 : {"product name" : "kitkat" , "product category" : "chocolate" , "MFG Date" : "22-06-2021" , "Price" : 50 , "Expiry Date" : "22-12-2021" ,"Weight" : "50gm","Quantity" : 300},
           107 : {"product name" : "Cashew" , "product category" : "Dry fruits" , "MFG Date" : "22-06-2021" , "Price" : 120 , "Expiry Date" : "22-12-2021" ,"Weight" : "100gm","Quantity" : 150},
           108 : {"product name" : "Raisin" , "product category" : "Dry fruits" , "MFG Date" : "22-06-2021" , "Price" : 80 , "Expiry Date" : "22-12-2021" ,"Weight" : "100gm","Quantity" : 200},
           109 : {"product name" : "Dry dates" , "product category" : "Dry fruits" , "MFG Date" : "22-06-2021" , "Price" : 90 , "Expiry Date" : "22-12-2021" ,"Weight" : "100gm","Quantity" : 180},
           110 : {"product name" : "Potato" , "product category" : "Vegetables" , "MFG Date" : "22-06-2021" , "Price" : 20 , "Expiry Date" : "22-12-2021" ,"Weight" : "1kg","Quantity" : 100},
           111 : {"product name" : "Onion" , "product category" : "Vegetables" , "MFG Date" : "22-06-2021" , "Price" : 30 , "Expiry Date" : "22-12-2021" ,"Weight" : "1kg","Quantity" : 80},
           112 : {"product name" : "Cauliflower" , "product category" : "Vegetables" , "MFG Date" : "22-06-2021" , "Price" : 60 , "Expiry Date" : "22-12-2021" ,"Weight" : "1kg","Quantity" : 90},
           113 : {"product name" : "Mango" , "product category" : "Fruits" , "MFG Date" : "22-06-2021" , "Price" : 50 , "Expiry Date" : "22-12-2021" ,"Weight" : "1kg","Quantity" : 110},
           114 : {"product name" : "Apple" , "product category" : "Fruits" , "MFG Date" : "22-06-2021" , "Price" : 150 , "Expiry Date" : "22-12-2021" ,"Weight" : "1kg","Quantity" : 120},
           115 : {"product name" : "kiwi" , "product category" : "Fruits" , "MFG Date" : "22-06-2021" , "Price" : 250 , "Expiry Date" : "22-12-2021" ,"Weight" : "1kg","Quantity" : 80}, 
           116 : {"product name" : "Cumin" , "product category" : "Spices" , "MFG Date" : "22-06-2021" , "Price" : 50 , "Expiry Date" : "22-12-2021" ,"Weight" : "100gm","Quantity" : 100},
           117 : {"product name" : "Coriander" , "product category" : "Spices" , "MFG Date" : "22-06-2021" , "Price" : 98 , "Expiry Date" : "22-12-2021" ,"Weight" : "100gm","Quantity" : 150},
           118 : {"product name" : "Red chilly" , "product category" : "Spices" , "MFG Date" : "22-06-2021" , "Price" : 30 , "Expiry Date" : "22-12-2021" ,"Weight" : "100gm","Quantity" : 180},
           119 : {"product name" : "Apple Juice" , "product category" : "Juice" , "MFG Date" : "22-06-2021" , "Price" : 130  , "Expiry Date" : "22-12-2021" ,"Weight" : "1L","Quantity" : 400},
           120 : {"product name" : "Mango Juice" , "product category" : "Juice" , "MFG Date" : "22-06-2021" , "Price" : 120 , "Expiry Date" : "22-12-2021" ,"Weight" : "1L","Quantity" : 500},
           121 : {"product name" : "Mixed Fruit Juice" , "product category" : "Juice" , "MFG Date" : "22-06-2021" , "Price" : 120 , "Expiry Date" : "22-12-2021" ,"Weight" : "1L","Quantity" : 1000},
           122 : {"product name" : "Pineapple Juice" , "product category" : "Juice" , "MFG Date" : "22-06-2021" , "Price" : 130 , "Expiry Date" : "22-12-2021" ,"Weight" : "1L","Quantity" : 500},
           123 : {"product name" : "Pomegranate Juice" , "product category" : "Juice" , "MFG Date" : "22-06-2021" , "Price" : 140 , "Expiry Date" : "22-12-2021" ,"Weight" : "1L","Quantity" :300 },
           124 : {"product name" : "Pepsi" , "product category" : "Cold Drink" , "MFG Date" : "22-06-2021" , "Price" : 100 , "Expiry Date" : "22-12-2021" ,"Weight" : "1.5L","Quantity" : 1000},
           125 : {"product name" : "Coka Cola" , "product category" : "Cold Drink" , "MFG Date" : "22-06-2021" , "Price" : 100 , "Expiry Date" : "22-12-2021" ,"Weight" : "1.5L","Quantity" : 1000},
           126 : {"product name" : "Montain Due" , "product category" : "Cold Drink" , "MFG Date" : "22-06-2021" , "Price" : 40 , "Expiry Date" : "22-12-2021" ,"Weight" : "500ml","Quantity" : 1000},
           127 : {"product name" : "Sprite" , "product category" : "Cold Drink" , "MFG Date" : "22-06-2021" , "Price" : 40 , "Expiry Date" : "22-12-2021" ,"Weight" : "500ml","Quantity" : 1000},
           128 : {"product name" : "Fanta" , "product category" : "Cold Drink" , "MFG Date" : "22-06-2021" , "Price" : 100 , "Expiry Date" : "22-12-2021" ,"Weight" : "1.5L","Quantity" : 1000},
           129 : {"product name" : "Marinda" , "product category" : "Cold Drink" , "MFG Date" : "22-06-2021" , "Price" : 100 , "Expiry Date" : "22-12-2021" ,"Weight" : "1.5L","Quantity" :1000 },
           130 : {"product name" : "Coka Cola" , "product category" : "Cold Drink" , "MFG Date" : "22-06-2021" , "Price" : 40 , "Expiry Date" : "22-12-2021" ,"Weight" : "500ml","Quantity" :1000 },
           131 : {"product name" : "Limca" , "product category" : "Cold Drink" , "MFG Date" : "22-06-2021" , "Price" : 40 , "Expiry Date" : "22-12-2021" ,"Weight" : "500ml","Quantity" : 1000},
          }

# %%
import json

# %%
js = json.dumps(record)

# %%
js
# Out:
# '{"101": {"product name": "Dairy milk", "product category": "chocolate", "MFG Date": "22-06-2021", "Price": 10, "Expiry Date": "22-12-2021", "Weight": "10gm", "Quantity": 800}, "102": {"product name": "5-star", "product category": "chocolate", "MFG Date": "22-06-2021", "Price": 10, "Expiry Date": "22-12-2021", "Weight": "10gm", "Quantity": 400}, "103": {"product name": "kitkat", "product category": "chocolate", "MFG Date": "22-06-2021", "Price": 10, "Expiry Date": "22-12-2021", "Weight": "10gm", "Quantity": 400}, "104": {"product name": "Dairy Milk silk", "product category": "chocolate", "MFG Date": "22-06-2021", "Price": 80, "Expiry Date": "22-12-2021", "Weight": "100gm", "Quantity": 800}, "105": {"product name": "5-star", "product category": "chocolate", "MFG Date": "22-06-2021", "Price": 60, "Expiry Date": "22-12-2021", "Weight": "70gm", "Quantity": 600}, "106": {"product name": "kitkat", "product category": "chocolate", "MFG Date": "22-06-2021", "Price": 50, "Expiry Date": "22-12
# ...

# %%
fd = open("record.json",'w')

fd.write(js)

fd.close()

# %%
fd = open("record.json",'r')
txt = fd.read()
fd.close()

# %%
record = json.loads(txt)

# %%
record
# Out:
# {'101': {'Expiry Date': '22-12-2021',
#   'MFG Date': '22-06-2021',
#   'Price': 10,
#   'Quantity': 800,
#   'Weight': '10gm',
#   'product category': 'chocolate',
#   'product name': 'Dairy milk'},
#  '102': {'Expiry Date': '22-12-2021',
#   'MFG Date': '22-06-2021',
#   'Price': 10,
#   'Quantity': 400,
#   'Weight': '10gm',
#   'product category': 'chocolate',
#   'product name': '5-star'},
#  '103': {'Expiry Date': '22-12-2021',
#   'MFG Date': '22-06-2021',
#   'Price': 10,
#   'Quantity': 400,
#   'Weight': '10gm',
#   'product category': 'chocolate',
#   'product name': 'kitkat'},
#  '104': {'Expiry Date': '22-12-2021',
#   'MFG Date': '22-06-2021',
#   'Price': 80,
#   'Quantity': 800,
#   'Weight': '100gm',
#   'product category': 'chocolate',
#   'product name': 'Dairy Milk silk'},
#  '105': {'Expiry Date': '22-12-2021',
#   'MFG Date': '22-06-2021',
#   'Price': 60,
#   'Quantity': 600,
#   'Weight': '70gm',
#   'product category': 'chocolate',
# ...

# %%
# From here our inventory management system application will start

# %%
name = input("Dear Customer!! Enter your name: ".title())
try:
  Contact_Number = int(input("Enter your contact number: ".title()))
except Exception as e:
    e = "Enter a valid number"
    print(e) 
    Contact_Number = int(input("Enter your contact number: ".title()))  
    
print("\nWelcome " + name + " here is the list of the products we have in our store: \n")
for products in record:
  print(products , "Product ID:")
  print("Product Name: " , record[products]['product name'])
  print("Product Category: " ,record[products]['product category'])
  print("Product Weight: " ,record[products]['Weight'])
  print("Product Price: " ,record[products]['Price'])
  print("Product Manufacturing Date: " ,record[products]['MFG Date'])
  print("Product Expiery Date: " ,record[products]['Expiry Date'])
  print("Product Quantity In Inventory: " , record[products]['Quantity'])
  print("******************************\n")
# Out:
# Dear Customer!! Enter Your Name: Aditya
# Enter Your Contact Number: eedew
# Enter a valid number
# Enter Your Contact Number: 73383991
#
# Welcome Aditya here is the list of the products we have in our store:
#
# 101 Product ID:
# Product Name:  Dairy milk
# Product Category:  chocolate
# Product Weight:  10gm
# Product Price:  10
# Product Manufacturing Date:  22-06-2021
# Product Expiery Date:  22-12-2021
# Product Quantity In Inventory:  800
# ******************************
#
# 102 Product ID:
# Product Name:  5-star
# Product Category:  chocolate
# Product Weight:  10gm
# Product Price:  10
# Product Manufacturing Date:  22-06-2021
# Product Expiery Date:  22-12-2021
# Product Quantity In Inventory:  400
# ******************************
#
# 103 Product ID:
# Product Name:  kitkat
# Product Category:  chocolate
# Product Weight:  10gm
# Product Price:  10
# Product Manufacturing Date:  22-06-2021
# Product Expiery Date:  22-12-2021
# Product Quantity In Inventory:  400
# ...

# %%
user_product = input("Enter the product id of the product you want to buy: ")

quantity_inv = record[user_product]['Quantity']
print("Maximum Quantity Available is: ", quantity_inv)
user_quantity = int(input("Enter the product quantity required: "))

quantity_check = True
while (quantity_check == True):
  if (user_quantity > quantity_inv): 
    print("Sorry, we don't have these many quantity of this product  in our inventory")
    print("You can purchase it to maximum " , quantity_inv ," quantity.")
    response = input("Do you still want to purchase this item?")
    if (response == "YES" or response == "yes" or response == "Yes"):
      user_quantity = int(input("Enter the product quantity required: "))
      for products in record:
            if(products == user_product):
              print("\n******************************")
              print("Product Name: " , record[products]['product name'])
              print("Product Category: " ,record[products]['product category'])
              print("Product Weight: " ,record[products]['Weight'])
              print("Product Price: " ,record[products]['Price'])
              print("Product Manufacturing Date: " ,record[products]['MFG Date'])
              print("Product Expiery Date: " ,record[products]['Expiry Date'])
              print("Product Quantity: " , user_quantity)
              bill_amount = user_quantity * record[products]['Price']
              print("******************************\n")
              quantity_check = False

              referal_code = input("Have Any Referal Code? YES/NO ")
              if (referal_code == "YES" or referal_code == "Yes" or referal_code == "yes"):
                while(referal_code == "yes" or referal_code == "YES" or referal_code == "Yes" ):
                  referal_code2 = input("Enter your referal code: ".title())
                  if (referal_code2 == "LESS500"):
                    if (bill_amount >= 1000):
                      print("Coupon has been successfully applied.")
                      print("******************************")
                      bill_amount = bill_amount - 500
                      referal_code = "NO"
                    else:
                      print("Cannot apply this coupon as your bill amount is ", 1000- bill_amount, " less." )
                      print("******************************")
                      referal_code = "NO"
                  elif (referal_code2 == "LESS50"):
                    if (bill_amount >= 500):
                      print("Coupon has been successfully applied.")
                      print("******************************")
                      bill_amount = bill_amount - 50
                      referal_code = "NO"
                    else:
                      print("Cannot apply this coupon as your bill amount is ", 500 - bill_amount, " less." )
                      print("******************************")
                      referal_code = "NO"
                  else:
                    print("This is not a valid referal code")
                    referal_code = input("Do you have any another referal code? YES/NO")

    else:
        response2 = input("Do you want another product?") 
        if (response2 == "YES" or response2 == "yes" or response2 == "Yes"):
          user_product = str(input("Enter the product id of the product you want to buy: "))
          user_quantity = int(input("Enter the product quantity required: "))
          if (user_quantity < quantity_inv):
            for products in record:
              if (products == user_product):
                print("\n******************************")
                print("Product Name: " , record[products]['product name'])
                print("Product Category: " ,record[products]['product category'])
                print("Product Weight: " ,record[products]['Weight'])
                print("Product Price: " ,record[products]['Price'])
                print("Product Manufacturing Date: " ,record[products]['MFG Date'])
                print("Product Expiery Date: " ,record[products]['Expiry Date'])
                print("Product Quantity: " , user_quantity)
                bill_amount = user_quantity * record[products]['Price']
                print("******************************\n")
                quantity_check = False

                referal_code = input("Have Any Referal Code? YES/NO ")
                if (referal_code == "YES" or referal_code == "Yes" or referal_code == "yes"):
                  while(referal_code == "yes" or referal_code == "YES" or referal_code == "Yes" ):
                    referal_code2 = input("Enter your referal code: ".title())
                    if (referal_code2 == "LESS500"):
                      if (bill_amount >= 1000):
                        print("Coupon has been successfully applied.")
                        print("******************************")
                        bill_amount = bill_amount - 500
                        referal_code = "NO"
                      else:
                        print("Cannot apply this coupon as your bill amount is ", 1000- bill_amount, " less." )
                        print("******************************")
                        referal_code = "NO"
                    elif (referal_code2 == "LESS50"):
                      if (bill_amount >= 500):
                        print("Coupon has been successfully applied.")
                        print("******************************")
                        bill_amount = bill_amount - 50
                        referal_code = "NO"
                      else:
                        print("Cannot apply this coupon as your bill amount is ", 500 - bill_amount, " less." )
                        print("******************************")
                        referal_code = "NO"
                    else:
                      print("This is not a valid referal code")
                      referal_code = input("Do you have any another referal code? YES/NO")
          else:
                quantity_check = True
        else:
          print("Sorry for your inconvinence.")
          print("Hope to see you again! we will not disappointed you next time.")
          quantity_check = False
          bill_amount = 0


  else:
    for products in record:
      if(products == user_product):
        print("\n******************************")
        print("Product Name: " , record[products]['product name'])
        print("Product Category: " ,record[products]['product category'])
        print("Product Weight: " ,record[products]['Weight'])
        print("Product Price: " ,record[products]['Price'])
        print("Product Manufacturing Date: " ,record[products]['MFG Date'])
        print("Product Expiery Date: " ,record[products]['Expiry Date'])
        print("Product Quantity: " , user_quantity)
        bill_amount = user_quantity * record[products]['Price']
        print("******************************\n")
        quantity_check = False

        referal_code = input("Have Any Referal Code? YES/NO ")
        if (referal_code == "YES" or referal_code == "Yes" or referal_code == "yes"):
          while(referal_code == "yes" or referal_code == "YES" or referal_code == "Yes" ):
            referal_code2 = input("Enter your referal code: ".title())
            if (referal_code2 == "LESS500"):
              if (bill_amount >= 1000):
                print("Coupon has been successfully applied.")
                print("******************************")
                bill_amount = bill_amount - 500
                referal_code = "NO"
              else:
                print("Cannot apply this coupon as your bill amount is ", 1000- bill_amount, " less." )
                print("******************************")
                referal_code = "NO"
            elif (referal_code2 == "LESS50"):
              if (bill_amount >= 500):
                print("Coupon has been successfully applied.")
                print("******************************")
                bill_amount = bill_amount - 50
                referal_code = "NO"
              else:
                print("Cannot apply this coupon as your bill amount is ", 500 - bill_amount, " less." )
                print("******************************")
                referal_code = "NO"
            else:
              print("This is not a valid referal code")
              referal_code = input("Do you have any another referal code? YES/NO")
        
print("\n******************************")
print("Customer Name: " + name)
print("Customer Contact Number: " , Contact_Number)
print("Total Billing Amount: Rs " , bill_amount)
print("Thanks for visiting")
print("******************************")
# Out:
# Enter the product id of the product you want to buy: 130
# Maximum Quantity Available is:  1000
# Enter the product quantity required: 20
#
# ******************************
# Product Name:  Coka Cola
# Product Category:  Cold Drink
# Product Weight:  500ml
# Product Price:  40
# Product Manufacturing Date:  22-06-2021
# Product Expiery Date:  22-12-2021
# Product Quantity:  20
# ******************************
#
# Have Any Referal Code? YES/NO yes
# Enter Your Referal Code: LESS500
# Cannot apply this coupon as your bill amount is  200  less.
# ******************************
#
# ******************************
# Customer Name: Aditya
# Customer Contact Number:  73383991
# Total Billing Amount: Rs  800
# Thanks for visiting
# ******************************

# %%
# updation of the inventory
fd = open("record.json",'r')
txt = fd.read()
fd.close()

for products in record:
  if(products == user_product):
    record[products]['Quantity'] = record[products]['Quantity'] - user_quantity

# %%
record
# Out:
# {'101': {'Expiry Date': '22-12-2021',
#   'MFG Date': '22-06-2021',
#   'Price': 10,
#   'Quantity': 800,
#   'Weight': '10gm',
#   'product category': 'chocolate',
#   'product name': 'Dairy milk'},
#  '102': {'Expiry Date': '22-12-2021',
#   'MFG Date': '22-06-2021',
#   'Price': 10,
#   'Quantity': 400,
#   'Weight': '10gm',
#   'product category': 'chocolate',
#   'product name': '5-star'},
#  '103': {'Expiry Date': '22-12-2021',
#   'MFG Date': '22-06-2021',
#   'Price': 10,
#   'Quantity': 400,
#   'Weight': '10gm',
#   'product category': 'chocolate',
#   'product name': 'kitkat'},
#  '104': {'Expiry Date': '22-12-2021',
#   'MFG Date': '22-06-2021',
#   'Price': 80,
#   'Quantity': 800,
#   'Weight': '100gm',
#   'product category': 'chocolate',
#   'product name': 'Dairy Milk silk'},
#  '105': {'Expiry Date': '22-12-2021',
#   'MFG Date': '22-06-2021',
#   'Price': 60,
#   'Quantity': 600,
#   'Weight': '70gm',
#   'product category': 'chocolate',
# ...
